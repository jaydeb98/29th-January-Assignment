# %%
1. Guido van Rossum developed the Python

2. Python supports several programming such as:
a. Procedural programming
b. Object-oriented programming (OOP)
c. Functional programming

3. Yes, Python is case-sensitive when dealing with identifiers. 
It means that variables, functions, classes, and other identifiers in Python are differentiated by their case. 
For example, "PWSKILLS" and "PWSkills" would be treated as two separate identifiers in Python.

4. The correct extension for Python files is ".py". 

5. Python code is typically interpreted. 
When you run a Python program, the source code is processed by the Python interpreter line by line, executing each line as it encounters it. 
This is known as the "interpreted" approach, where the interpreter directly executes the code without prior compilation.

6. The main blocks of code used in Python are:

Functions: It is defined by using the def keyword, and this functions allow you to group related code together and reuse it.
Conditional Statements: Such as if, elif, and else.
Loops: Such as for and while, used for repeating a block of code multiple times.
Classes: Defined using the class keyword.

7. The character used to give single-line comments in Python is the hash symbol (#).
    
8. To find the version of Python we can use "sys.version".
    
9. Python supports the creation of anonymous functions at runtime using a construct called "lambda functions" or "lambda expressions."
    
10. In Python, "pip" stands for "pip installs packages" or "Pip Installs Python." 
    
11.  Some commonly used built-in functions in Python include:

print(): Used to display output on the console.
len(): Returns the length of an object (such as a string, list, or tuple).
input(): Reads input from the user via the console.
range(): Generates a sequence of numbers.
type(): Returns the type of an object.
int(), float(), str(): Convert values to integer, float, or string, respectively.
max(), min(): Returns the maximum or minimum value from a sequence.
sum(): Returns the sum of all elements in a sequence.
sort(): Returns a sorted version of a sequence.

12. In Python, the maximum possible length of an identifier is not explicitly defined. 
    However, according to the Python style guide, the recommended maximum length for an identifier is 79 characters. 
    
13. The Benefits of using Python are:

a. Readability and simplicity
b. Large standard library
c. Portability
d. Extensive third-party ecosystem
e. Integration capabilities
f. Rapid prototyping and development
g. Active community and support
    
14. Memory management in Python is handled automatically through a combination of techniques, including garbage collection and reference counting. 
    Python uses a garbage collector to reclaim memory occupied by objects that are no longer in use. 
    Reference counting keeps track of the number of references to an object, and when the reference count reaches zero, the memory occupied by the object is freed. 
    
15. To install Python on Windows and set path variables, you can follow these steps:

i. Visit the official Python website (https://www.python.org) and navigate to the Downloads section.

ii. Download the latest Python installer for Windows, based on your system architecture (32-bit or 64-bit).

iii. Run the installer and select the option to "Install Now."

iv. On the next screen, make sure to check the box that says "Add Python to PATH." This will automatically set the necessary environment variables.

v. Proceed with the installation by clicking "Install."

vi. Once the installation is complete, open the command prompt or PowerShell and type python --version to verify that Python is installed correctly. You should see the version number displayed.

vii. To confirm that the path variables are set correctly, you can type python in the command prompt and press Enter. The Python interactive shell should start without any errors.
    
16. Yes, indentation is required in Python. 
    Unlike many other programming languages that use braces or other explicit symbols for defining blocks of code, Python uses indentation to determine the grouping and hierarchy of statements.
